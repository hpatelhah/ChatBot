# %% [markdown]
# # Workflow Designs:
#
# basic: start >>> retriever >>> generator >>> end
# ReACT: start >>> retriever >>> generator with tools >>> end

# %%
import sys, os
sys.path.insert(0, "/home/sagemaker-user/src")
from langgraph.graph import StateGraph, END, START
from state.rag_state import RAGState
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 sys.path.insert(0, "/home/sagemaker-user/src")
#       3 from langgraph.graph import StateGraph, END, START
# ----> 4 from state.rag_state import RAGState
#
# File ~/src/state/rag_state.py:3
#       1 from typing import List
#       2 from pydantic import BaseModel
# ----> 3 from langchain.schema import Document
#       7 class RAGState(BaseModel):
#       8     """State object for rag workflow"""
#
# File /opt/conda/lib/python3.12/site-packages/langchain/schema/__init__.py:8
#       6 from langchain_core.documents import BaseDocumentTransformer, Document
#       7 from langchain_core.exceptions import LangChainException, OutputParserException
# ----> 8 from langchain_core.memory import BaseMemory
#       9 from langchain_core.messages import (
#      10     AIMessage,
#      11     BaseMessage,
#    (...)
#      19     messages_to_dict,
#      20 )
#      21 from langchain_core.messages.base import message_to_dict
#
# ModuleNotFoundError: No module named 'langchain_core.memory'

# %%
# !pwd
# Out:
# /home/sagemaker-user/src/graph_builder
